# %%
help ("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.42.0
# IPython             babel               mailcap             statistics
# __future__          backcall            markupsafe          string
# __hello__           base64              marshal             stringprep
# __phello__          bdb                 math                struct
# _abc                binascii            matplotlib_inline   subprocess
# _aix_support        bisect              mimetypes           sunau
# _argon2_cffi_bindings bleach              mistune             symtable
# _ast                bs4                 mmap                sys
# _asyncio            builtins            mmapfile            sysconfig
# _bisect             bz2                 mmsystem            tabnanny
# _blake2             cProfile            modulefinder        tarfile
# _bz2                calendar            msilib              telnetlib
# ...

# %%
help ("modules")
